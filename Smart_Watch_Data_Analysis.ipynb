# %%
import pandas as pd
import numpy as np

df = pd.read_excel("C:/Users/mansi desai/Desktop/dailyActivity_merged.xlsx")
df.head(31)
# Out:
#             Id         ActivityDate  TotalSteps  TotalDistance  \
# 0   1503960366  2016-12-04 00:00:00       13162           8.50
# 1   1503960366            4/13/2016       10735           6.97
# 2   1503960366            4/14/2016       10460           6.74
# 3   1503960366            4/15/2016        9762           6.28
# 4   1503960366            4/16/2016       12669           8.16
# 5   1503960366            4/17/2016        9705           6.48
# 6   1503960366            4/18/2016       13019           8.59
# 7   1503960366            4/19/2016       15506           9.88
# 8   1503960366            4/20/2016       10544           6.68
# 9   1503960366            4/21/2016        9819           6.34
# 10  1503960366            4/22/2016       12764           8.13
# 11  1503960366            4/23/2016       14371           9.04
# 12  1503960366            4/24/2016       10039           6.41
# 13  1503960366            4/25/2016       15355           9.80
# ...

# %%
df.isnull().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
# combining all the same domain column for ease...

# Minutes
df['TotalMinutes'] = df["VeryActiveMinutes"] + df["FairlyActiveMinutes"] + df["LightlyActiveMinutes"] + df["SedentaryMinutes"]
print(df["TotalMinutes"].head(31))
df.head(31)

# Distance
# Out:
# 0     1094
# 1     1033
# 2     1440
# 3      998
# 4     1040
# 5      761
# 6     1440
# 7     1120
# 8     1063
# 9     1076
# 10    1440
# 11    1056
# 12     991
# 13    1117
# 14    1166
# 15    1440
# 16    1047
# 17    1086
# 18    1015
# 19    1044
# 20    1131
# 21    1144
# 22    1440
# 23    1176
# 24    1073
# 25    1091
# 26     829
# 27    1098
# 28    1037
# 29     979
# 30    1440
# Name: TotalMinutes, dtype: int64
#             Id         ActivityDate  TotalSteps  TotalDistance  \
# 0   1503960366  2016-12-04 00:00:00       13162           8.50
# 1   1503960366            4/13/2016       10735           6.97
# 2   1503960366            4/14/2016       10460           6.74
# 3   1503960366            4/15/2016        9762           6.28
# 4   1503960366            4/16/2016       12669           8.16
# 5   1503960366            4/17/2016        9705           6.48
# 6   1503960366            4/18/2016       13019           8.59
# ...

# %%
df["ActivityDate"] = pd.to_datetime(df["ActivityDate"],format = "%m%d%y")
print(df.info)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     449             try:
# --> 450                 values, tz = conversion.datetime_to_datetime64(arg)
#     451                 dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-9f1363cd0df0> in <module>
# ----> 1 df["ActivityDate"] = pd.to_datetime(df["ActivityDate"],format = "%m%d%y")
#       2 print(df.info)
#
# ...
